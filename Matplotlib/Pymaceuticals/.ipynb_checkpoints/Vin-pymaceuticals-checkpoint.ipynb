# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# # File to Load (Remember to Change These)
# mouse_drug_data_to_load = "data/mouse_drug_data.csv"
# clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data


# Combine the data into a single dataset


# Display the data table for preview

# %%
# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"



# Read the Mouse and Drug Data and the Clinical Trial Data

drug_mouse_df = pd.read_csv(mouse_drug_data_to_load)
clinical_data_df = pd.read_csv(clinical_trial_data_to_load)
print(drug_mouse_df.head())
clinical_data_df.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset and display head
trial_df = pd.merge(clinical_data_df,drug_mouse_df, how='left', on = 'Mouse ID' )
trial_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0                45.0                 0  Capomulin
# 1     f932          0                45.0                 0   Ketapril
# 2     g107          0                45.0                 0   Ketapril
# 3     a457          0                45.0                 0   Ketapril
# 4     c819          0                45.0                 0   Ketapril

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# # Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
# trial_drug_timpoint_df = trial_df.groupby(["Drug","Timepoint"])

# # Convert to DataFrame
# trial_drug_timpoint_df = trial_drug_timpoint_df["Tumor Volume (mm3)"].mean()
# trial_drug_timpoint_df = trial_drug_timpoint_df.reset_index()
# # Preview DataFrame
# trial_drug_timpoint_df.head()

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mean_drug_timpoint_df = trial_df.groupby(["Drug","Timepoint"])

# Convert to DataFrame
mean_drug_timpoint_df = mean_drug_timpoint_df["Tumor Volume (mm3)"].mean()
mean_drug_timpoint_df = mean_drug_timpoint_df.reset_index()
# Preview DataFrame
mean_drug_timpoint_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
# bring in required dependencies
from scipy.stats import sem

 
stderror_drug_timpoint_df = trial_df.groupby(["Drug","Timepoint"])

# Convert to DataFrame
stderror_drug_timpoint_df = stderror_drug_timpoint_df["Tumor Volume (mm3)"].sem()
stderror_drug_timpoint_df = stderror_drug_timpoint_df.reset_index()
# Preview DataFrame
stderror_drug_timpoint_df.head(10)
#print(type(stderror_drug_timpoint_df))
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731
# 5  Capomulin         25            0.881642
# 6  Capomulin         30            0.934460
# 7  Capomulin         35            1.052241
# 8  Capomulin         40            1.223608
# 9  Capomulin         45            1.223977

# %%
# Minor Data Munging to Re-Format the Data Frames

stderr_tumorvol_df = stderror_drug_timpoint_df.pivot(index = "Timepoint", columns = "Drug",values = 'Tumor Volume (mm3)')

pivot_df = mean_drug_timpoint_df.pivot(index = "Timepoint", columns = "Drug",values = 'Tumor Volume (mm3)')
pivot_df
# Preview that Reformatting worked
#print(type(stderr_tumorvol_df))
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334
# 25         55.504138  38.974300  56.166123  55.432935
# 30         58.196374  38.703137  59.826738  57.713531
# 35         60.350199  37.451996  62.440699  60.089372
# 40         63.045537  36.574081  65.356386  62.916692
# 45         66.258529  34.955595  68.438310  65.960888

# %%
# Generate the Plot (with Error Bars)
ax = pivot_df[["Capomulin", "Infubinol","Ketapril",'Placebo']]\
            .plot( yerr = stderr_tumorvol_df, figsize= (10,6), legend = True)

ax.set_xlabel("Time (Days)")
ax.set_ylabel("Mean Tumor Vol (mm3)")


pivot_df[["Capomulin","Infubinol", "Ketapril", "Placebo"]]\
            .plot(grid = True,style =['^','o','>','v'], markersize =7,legend =True, \
                  label = "Tumor Response to Treatment",ax = ax )

plt.tight_layout()
plt.title("Tumor Response to Treatment")
plt.savefig("Picture/tumor_vol.png")
plt.show()
# Save the Figure
# Show the Figure

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# Store the Mean Meta.Site Data Grouped by Drug and Timepoint 
mean_metasite_df = trial_df.groupby(["Drug","Timepoint"])

# Convert to DataFrame
mean_metasite_df = mean_metasite_df['Metastatic Sites'].mean()

#mean_metasite_df= mean_metasite_df.reset_index()
# Preview DataFrame
mean_metasite_df.head()
# Out:
# Drug       Timepoint
# Capomulin  0            0.000000
#            5            0.160000
#            10           0.320000
#            15           0.375000
#            20           0.652174
# Name: Metastatic Sites, dtype: float64

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame
# Store the Mean Meta. Site Grouped by Drug and Timepoint 
stderror_metasite_df = trial_df.groupby(["Drug","Timepoint"])

# Convert to DataFrame
stderror_metasite_df = stderror_metasite_df['Metastatic Sites'].sem()

# Preview DataFrame
stderror_metasite_df.head()
#type(stderror_metasite_df)
# Out:
# Drug       Timepoint
# Capomulin  0            0.000000
#            5            0.074833
#            10           0.125433
#            15           0.132048
#            20           0.161621
# Name: Metastatic Sites, dtype: float64

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# Minor Data Munging to Re-Format the Data Frames
stderror_metasite_df= stderror_metasite_df.reset_index()
stderr_pivot_metasite_df = stderror_metasite_df.pivot(index ='Timepoint', columns = 'Drug', values = 'Metastatic Sites')

mean_metasite_df= mean_metasite_df.reset_index()
pivot_metasite_df = mean_metasite_df.pivot(index ='Timepoint', columns = 'Drug', values = 'Metastatic Sites')
#mean_metasite_df.pivot(index = "Timepoint", columns = "Drug",values = 'Metastatic Sites')
pivot_metasite_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118
# 25         1.357143  0.652174  1.157895   1.687500
# 30         1.615385  0.782609  1.388889   1.933333
# 35         2.300000  0.952381  1.562500   2.285714
# 40         2.777778  1.100000  1.583333   2.785714
# 45         2.571429  1.250000  1.727273   3.071429

# %%
# Generate the Plot (with Error Bars)

ax = pivot_metasite_df[["Capomulin", "Infubinol","Ketapril",'Placebo']]\
            .plot( yerr = stderr_pivot_metasite_df, figsize= (10,6), legend = True)

# ax.set_xlabel("Time (Days)")
# ax.set_ylabel("Meta Sites")


pivot_metasite_df[["Capomulin","Infubinol", "Ketapril", "Placebo"]]\
            .plot(grid = True,style =['^','o','>','v'], markersize =7,legend =True, \
                  label = "Meta",ax = ax )

plt.title('Metastatic Spread During Treatment')
plt.xlabel('Time (Days)')
plt.ylabel('Meta. Sites')

plt.savefig("Picture/Metastatic Sites.png")


plt.show()

# Save the Figure

# Show the Figure

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

count_mice_df = trial_df.groupby(['Drug','Timepoint'])
# Convert to DataFrame
count_mice_df = count_mice_df['Mouse ID'].count()
count_mice_df = count_mice_df.reset_index()
count_mice_df = count_mice_df.rename(columns = {'Mouse ID': 'Mouse Count'})
# Preview DataFrame
count_mice_df.head()
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame
pivot_mouse_count = count_mice_df.pivot(index ='Timepoint', columns = 'Drug', values = 'Mouse Count')
pivot_mouse_percent = (pivot_mouse_count.div(pivot_mouse_count.iloc[1,0], axis=0))*100

pivot_mouse_percent*100

pivot_mouse_count
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17
# 25               14        23        19         16
# 30               13        23        18         15
# 35               10        21        16         14
# 40                9        20        12         14
# 45                7        20        11         14

# %%
# Generate the Plot (Accounting for percentages)
ax = pivot_mouse_percent[["Capomulin","Infubinol", "Ketapril", "Placebo"]].plot(legend = True)

pivot_mouse_percent[["Capomulin","Infubinol", "Ketapril", "Placebo"]]\
            .plot(grid = True,style =['^','o','>','v'], markersize =7,legend =True, \
                  label = "Survival Rate",ax = ax )
# Save the Figure
plt.title('Survival During Treatment')
plt.xlabel("Time (days)")
plt.ylabel('Survival rate (%)')
plt.savefig("Picture/Survival Rate.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# First attept to get the graph.  Please evaluate/grade next cell .
# df1 = pivot_df.iloc[[0,9],:]
# #print(df1)
# # print(type(df1))
# percentchange_df = df1.pct_change()
# drug_list = ["Capomulin","Infubinol", "Ketapril", "Placebo"]
# percentchange_df[drug_list].plot.bar()

# # the above code works to get the plot but the color coding does not work correctly.



# list1=percentchange_df.iloc[1]
# type(list1)
#list1 = df1.iloc[:]
#print(percentchange_df)
#list1

# print(type(df1))
# print(df1.iloc[1])
#print(list1[0])


# for i in range (4):
#     if list1[i] < 0:
#         assigned_color = "blue"
#         print(list1[i])
#         df1[drug_list[i]].plot.bar( color =assigned_color, legend = True)
#     else:
#         print(list1[i])
#         assigned_color = "red"
#         df1[drug_list[i]].plot(kind = "bar", color =assigned_color)

# %%
df1 = pivot_df.iloc[[0,9],:]
#print(df1)
# print(type(df1))
percentchange_df = df1.pct_change()
drug_list = ["Capomulin","Infubinol", "Ketapril", "Placebo"]
#percentchange_df[drug_list].plot.bar()
list_percentchange=percentchange_df.iloc[1]
print(list_percentchange)

r1  = percentchange_df.iloc[[1]]
# # print(type(r1))
# # print(r1)
r2 = r1.iloc[[0],[0,2,3,5]]
t1 = r2[r2.iloc[[0]]<0]
t2 = r2[r2.iloc[[0]]>0]
t3 = t1.T
t4 = t2.T


plt.bar(t3.index.values, t3.iloc[:,0] ,color='r')
plt.bar(t4.index.values, t4.iloc[:,0] ,color='g')
plt.title('Tumor Change Over 45 days')
plt.xlabel("Time (Days)")
plt.ylabel("% Tumor Volume change")

plt.savefig("Picture/Summary.png")

# I tried using loop to splice the data.  I need help to understand why the following logic did not work.
# list1=percentchange_df.iloc[1]
# type(list1)
# #list1 = df1.iloc[:]
# #print(percentchange_df)
# #list1

# # print(type(df1))
# # print(df1.iloc[1])
# #print(list1[0])


# # for i in range (4):
# #     if list1[i] < 0:
# #         assigned_color = "blue"
# #         print(list1[i])
# #         df1[drug_list[i]].plot.bar( color =assigned_color, legend = True)
# #     else:
# #         print(list1[i])
# #         assigned_color = "red"
# #         df1[drug_list[i]].plot(kind = "bar", color =assigned_color)
# Out:
# Drug
# Capomulin   -0.194753
# Ceftamin     0.425165
# Infubinol    0.461235
# Ketapril     0.570288
# Naftisol     0.539233
# Placebo      0.512980
# Propriva     0.472412
# Ramicane    -0.223209
# Stelasyn     0.520851
# Zoniferol    0.465798
# Name: 45, dtype: float64

# %%
Percentchange_tuple = tuple (list_percentchange)
Percentchange_tuple
# Out:
# (-0.19475302667894168,
#  0.4251649185589741,
#  0.4612347172785185,
#  0.5702879468660607,
#  0.5392334713476923,
#  0.5129796048315152,
#  0.47241174863206337,
#  -0.22320900462766669,
#  0.5208513428789896,
#  0.4657975086509525)

# %% [markdown]
# # Conclusion
# 1] Capomulin is the only drug that showed the best results in shrinking the tumor, reducing metastasis and in survival rate than other drugs
# 2] Other drugs showed similar results to placibo which means it is better of taking no drug instead of taking any of the other drugs other than Capomulin
# 3] Standard error in Capomulin is relatively smaller than standard error in other drug.  This means chances of variation in Capomulin are smaller. Hence one ( in this case mouse) can expect results closer to expected when treated with Capomulin.
